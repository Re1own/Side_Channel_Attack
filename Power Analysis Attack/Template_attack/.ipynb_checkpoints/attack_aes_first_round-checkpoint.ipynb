# %% [markdown]
# ## Template Attack the first key byte

# %%
import numpy as np

tempPText = np.load("D:\\Side_Channel_Attack\\Traces\\AES_5000_varibale_key\\p.npy")
tempTraces = np.load("D:\\Side_Channel_Attack\\Traces\\AES_5000_varibale_key\\traces.npy")
tempKey = np.load("D:\\Side_Channel_Attack\\Traces\\AES_5000_varibale_key\\k.npy")

# %%
sbox=(
    )

# %%
tempSbox = [sbox[tempPText[i][0] ^ tempKey[i][0]] for i in range(len(tempPText))]

# %%
hw = [bin(x).count("1") for x in range(256)]
tempHW = [hw[s] for s in tempSbox]

# %%
tempTracesHW = [[] for _ in range(9)]

# %%
for i in range(len(tempTraces)):
    HW = tempHW[i]
    tempTracesHW[HW].append(tempTraces[i])

# %%
tempTracesHW = [np.array(tempTracesHW[HW]) for HW in range(9)]

# %%
tempMeans = np.zeros((9, len(tempTraces[0])))

# %%
for i in range(9):
    tempMeans[i] = np.average(tempTracesHW[i], 0)

# %%
import matplotlib.pyplot as plt
for i in range(100):
    
    plt.plot(tempTraces[1][1000:2000])
plt.show()

# %%
plt.plot(tempTracesHW[1])
plt.show()

# %%
len(tempTracesHW[8])
# Out:
# 16

# %%
tempMeans[5]
# Out:
# array([ 0.13814538,  0.07390155, -0.04029782,  0.07966178,  0.13481441,
#         0.06209512, -0.0507862 ,  0.07722285,  0.01183812, -0.08174687,
#        -0.19267596,  0.0438129 ,  0.13597329,  0.05097211, -0.03611303,
#         0.17191007,  0.21536733,  0.07745642, -0.05850158,  0.11705037,
#         0.14791033,  0.0111066 , -0.10924057,  0.09211543,  0.15053001,
#         0.03656916, -0.06974846,  0.13853115,  0.19149392,  0.06918352,
#        -0.05091591,  0.14291534,  0.18643981,  0.05581491, -0.06642154,
#         0.12844854,  0.17503422,  0.04948299, -0.0677715 ,  0.1322887 ,
#         0.18166176,  0.05696525, -0.06069795,  0.13569655,  0.1825493 ,
#         0.05504135, -0.06421505,  0.1306249 ,  0.17825233,  0.06078247,
#        -0.06033084,  0.13053003,  0.01921877, -0.01425772, -0.09067778,
#         0.13041988,  0.25476119,  0.21633602,  0.09278288,  0.18238204,
#         0.1965975 ,  0.08951508, -0.05922254,  0.0412202 ,  0.09740739,
#         0.04336643, -0.05564361,  0.08528736,  0.16346316,  0.11394061,
#         0.00604124,  0.12398769,  0.17562254,  0.10122349, -0.02680421,
#         0.0814436 ,  0.13159562,  0.06329132, -0.05308642,  0.06907606,
#         0.13161338,  0.07315991, -0.03780853,  0.08503962,  0.14664309,
#         0.08299635, -0.03374424,  0.08469746,  0.14206939,  0.07676964,
#        -0.03890558,  0.08083617,  0.14120905,  0.0789143 , -0.03493909,
#         0.08677311,  0.1480614 ,  0.08547035, -0.03020195,  0.09012251,
#         0.14878977,  0.0840752 , -0.0302568 ,  0.08851491,  0.14805443,
#         0.08371078, -0.03073991,  0.08827639,  0.14878663,  0.08592738,
#        -0.02904599,  0.09204866,  0.15428653,  0.08449132, -0.03367432,
#         0.08942853,  0.15411006,  0.08622683, -0.032033  ,  0.09091181,
#         0.15329423,  0.08653122, -0.03365229,  0.09051345,  0.15317014,
#         0.08651121, -0.0329356 ,  0.09070027,  0.15382208])

# %%
import matplotlib.pyplot as plt
plt.plot(tempMeans[3])
plt.grid()
plt.show()

# %%
plt.plot(abs(tempMeans[0]-tempMeans[1]))
plt.grid()
plt.show()

# %%
plt.plot(abs(tempMeans[0]-tempMeans[2]))
plt.grid()
plt.show()

# %%
plt.plot(abs(tempMeans[0]-tempMeans[7]))
plt.grid()
plt.show()

# %%
tempMeans[8]
# Out:
# array([ 0.14328003,  0.06924438, -0.04495239,  0.08099365,  0.1388092 ,
#         0.0668335 , -0.04039001,  0.07691956,  0.01858521, -0.06932068,
#        -0.1857605 ,  0.04396057,  0.1308136 ,  0.04553223, -0.04696655,
#         0.17004395,  0.21372986,  0.07626343, -0.06274414,  0.12130737,
#         0.15248108,  0.01123047, -0.11334229,  0.09289551,  0.15208435,
#         0.03440857, -0.06678772,  0.13543701,  0.19294739,  0.06616211,
#        -0.05981445,  0.13807678,  0.19485474,  0.0604248 , -0.06044006,
#         0.1237793 ,  0.17785645,  0.0552063 , -0.06387329,  0.12379456,
#         0.17475891,  0.04298401, -0.07131958,  0.12478638,  0.1769104 ,
#         0.05691528, -0.06280518,  0.14237976,  0.18878174,  0.0615387 ,
#        -0.05865479,  0.12397766,  0.01681519, -0.01695251, -0.09947205,
#         0.12515259,  0.25157166,  0.20718384,  0.08985901,  0.18341064,
#         0.19459534,  0.09677124, -0.05845642,  0.04104614,  0.09664917,
#         0.04710388, -0.05082703,  0.08972168,  0.16741943,  0.12675476,
#         0.01222229,  0.12495422,  0.1802063 ,  0.10217285, -0.01774597,
#         0.08163452,  0.1269989 ,  0.0561676 , -0.06796265,  0.05578613,
#         0.12306213,  0.0668335 , -0.0381012 ,  0.07983398,  0.1471405 ,
#         0.08952332, -0.02824402,  0.09362793,  0.15534973,  0.08633423,
#        -0.03102112,  0.08772278,  0.15031433,  0.07983398, -0.03585815,
#         0.08018494,  0.1494751 ,  0.08198547, -0.03443909,  0.07975769,
#         0.14685059,  0.07154846, -0.03787231,  0.08598328,  0.14570618,
#         0.09352112, -0.02209473,  0.09237671,  0.15272522,  0.09912109,
#        -0.01654053,  0.10090637,  0.15953064,  0.08638   , -0.03210449,
#         0.09451294,  0.15058899,  0.08763123, -0.03387451,  0.08103943,
#         0.14169312,  0.07519531, -0.04389954,  0.07525635,  0.14816284,
#         0.09291077, -0.0216217 ,  0.09216309,  0.15510559])

# %%
tempMeans[0]
# Out:
# array([ 1.45000000e-01,  7.67480469e-02, -3.56640625e-02,  7.49316406e-02,
#         1.27822266e-01,  4.42871094e-02, -6.70019531e-02,  6.43554688e-02,
#         7.22656250e-04, -8.01562500e-02, -1.90781250e-01,  5.34375000e-02,
#        0.0909264 , 0.0522442 , 0.09610986, 0.13155986, 0.10365093,
#        0.06539712, 0.07228669, 0.09774619, 0.05530046, 0.08184418,
#        0.12707488, 0.14444867, 0.13295005, 0.09052302, 0.07400479,
#        0.13581633, 0.07212909, 0.14174133, 0.09579702, 0.10459598,
#        0.08935032, 0.07844358, 0.07563371, 0.08429313, 0.12893751,
#        0.09792811, 0.1863732 , 0.15453231, 0.12402055, 0.09346312,
#        0.05520721, 0.12616902, 0.22907759, 0.18359552, 0.10413525,
#        0.10653112, 0.10888957, 0.07012028, 0.06082019, 0.12086875,
#        0.08657074, 0.09234572, 0.13972915, 0.04277124, 0.02519663,
#        0.0683136 , 0.12355453, 0.04504572, 0.0516625 , 0.04666732,
#        0.09561968, 0.09659221, 0.05899612, 0.05365379, 0.16631824,
#        0.14200156, 0.04616596, 0.11943455, 0.06928051, 0.1823843 ,
#        0.08134812, 0.10300093, 0.10231103, 0.16020711, 0.17180901,
#        0.15895637, 0.12950665, 0.06250913, 0.08757527, 0.0584608 ,
#        0.08644294, 0.08749298, 0.12906589, 0.19263189, 0.1210572 ,
#        0.12889284, 0.11068777, 0.1458361 , 0.04367713, 0.02944923,
#        0.07876976, 0.05753647, 0.03942337, 0.10566185, 0.12564604,
#        0.08128833, 0.18913354, 0.11427543, 0.05196753, 0.06468738,
#        0.14250942, 0.13238394, 0.07245203, 0.05672263, 0.16902481,
#        0.21284929, 0.13004406, 0.18022015, 0.12895547, 0.06675415,
#        0.07286632, 0.08992802, 0.09313775, 0.07237491, 0.13470138,
#        0.12301368, 0.12473314, 0.14129572, 0.1798582 , 0.0750198 ,
#        0.08301488, 0.12300181, 0.03109338, 0.03653992])

# %%
plt.plot(tempSumDiff)
plt.grid()
plt.show()

# %%
# Some settings that we can change
numPOIs = 5        # How many POIs do we want?
POIspacing = 5     # How far apart do the POIs have to be?

# Make an empty list of POIs
POIs = []

# Repeat until we have enough POIs
for i in range(numPOIs):
    # Find the biggest peak and add it to the list of POIs
    nextPOI = tempSumDiff.argmax()
    POIs.append(nextPOI)
    
    # Zero out some of the surrounding points
    # Make sure we don't go out of bounds
    poiMin = max(0, nextPOI - POIspacing)
    poiMax = min(nextPOI + POIspacing, len(tempSumDiff))
    for j in range(poiMin, poiMax):
        tempSumDiff[j] = 0

# Make sure they look okay
print(POIs)
# Out:
# [6, 47, 110, 88, 101]

# %%
meanMatrix = np.zeros((9, numPOIs))
for HW in range(9):
    for i in range(numPOIs):
        meanMatrix[HW][i] = tempMeans[HW][POIs[i]]

# %%
import numpy as np
def cov(x, y):
    # Find the covariance between two 1D lists (x and y).
    # Note that var(x) = cov(x, x)
    return np.cov(x, y)[0][1]

covMatrix  = np.zeros((9, numPOIs, numPOIs))
for HW in range(9):
    for i in range(numPOIs):
        for j in range(numPOIs):
            x = tempTracesHW[HW][:,POIs[i]]
            y = tempTracesHW[HW][:,POIs[j]]
            covMatrix[HW,i,j] = cov(x, y)

# %%
print(meanMatrix)
print(covMatrix[0])
# Out:
# [[-0.06700195  0.12001953 -0.03818359  0.1478418   0.09237305]
#  [-0.05082351  0.12829903 -0.02692433  0.14254526  0.08285914]
#  [-0.05137617  0.13184547 -0.03101312  0.14267841  0.08433243]
#  [-0.05057627  0.13053385 -0.02846885  0.14185795  0.08377721]
#  [-0.05258573  0.1293093  -0.02961506  0.14269563  0.0843048 ]
#  [-0.0507862   0.1306249  -0.02904599  0.14206939  0.0840752 ]
#  [-0.0523009   0.13010038 -0.02958378  0.14131964  0.08314275]
#  [-0.0533462   0.12543828 -0.03165592  0.13673346  0.0856463 ]
#  [-0.04039001  0.14237976 -0.01654053  0.15534973  0.07154846]]
# [[ 4.56005732e-04  2.78094411e-04  1.58996880e-04  4.08221285e-05
#   -1.95128322e-04]
#  [ 2.78094411e-04  8.18674763e-04  3.40349972e-04  1.79549058e-05
#   -2.89257367e-04]
#  [ 1.58996880e-04  3.40349972e-04  2.78648237e-03  1.02345149e-04
#   -2.29764481e-04]
#  [ 4.08221285e-05  1.79549058e-05  1.02345149e-04  7.69719879e-04
#   -9.37855244e-05]
#  [-1.95128322e-04 -2.89257367e-04 -2.29764481e-04 -9.37855244e-05
#    7.66927401e-04]]

# %%
atkTraces = np.load("D:\\Side_Channel_Attack\\Traces\\AES_5000_fixed_key\\traces.npy")
atkPText = np.load("D:\\Side_Channel_Attack\\Traces\\AES_5000_fixed_key\\p.npy")
atkKey = np.load("D:\\Side_Channel_Attack\\Traces\\AES_5000_fixed_key\\k.npy")

# %%
P_k = np.zeros(256)

# %%
from scipy.stats import multivariate_normal

# %%
atkKey
# Out:
# array([[ 43, 126,  21, ..., 207,  79,  60],
#        [ 43, 126,  21, ..., 207,  79,  60],
#        [ 43, 126,  21, ..., 207,  79,  60],
#        ...,
#        [ 43, 126,  21, ..., 207,  79,  60],
#        [ 43, 126,  21, ..., 207,  79,  60],
#        [ 43, 126,  21, ..., 207,  79,  60]], dtype=uint8)

# %%
#result1  5000 traces
for j in range(5):
    # Grab key points and put them in a matrix
    a = [atkTraces[j][POIs[i]] for i in range(len(POIs))]
    
    # Test each key
    for k in range(256):
        # Find HW coming out of sbox
        HW = hw[sbox[atkPText[j][0] ^ k]]
    
        # Find p_{k,j}
        rv = multivariate_normal(meanMatrix[HW], covMatrix[HW])
        p_kj = rv.pdf(a)
   
        # Add it to running total
        P_k[k] += np.log(p_kj)

    # Print our top 5 results so far
    # Best match on the right
    print(P_k.argsort()[-5:])
# Out:
# [229 230 201 127  43]
# [229 122 230  43  71]
# [ 35  43 201  89  71]
# [ 35  89 201 182  71]
# [ 43 251 201 182  71]

# %%
The above result shows 43 almost in each rows, so the first byte are successfully been attacked
# Out:
#   Cell In[1], line 1
#     The above result shows 43 almost in each rows, so the first byte are successfully been attacked
#         ^
# SyntaxError: invalid syntax
