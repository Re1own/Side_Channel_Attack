# %%
import numpy as np
import matplotlib.pyplot as plt
tempTraces = np.load("E:\\myhub\\SCA_Traces\\Firmware_aes_vari\\traces.npy")
tempPText = np.load("E:\\myhub\\SCA_Traces\\Firmware_aes_vari\\p.npy")
tempKey = np.load("E:\\myhub\\SCA_Traces\\Firmware_aes_vari\\k.npy")

# %%
#The sbox is standard
sbox=(
    )

# %%
#attack point, we attack the first round of AES. The first round only do the following operations
tempSbox = [sbox[tempPText[i][0] ^ tempKey[i][0]] for i in range(len(tempPText))]

# %%
#calculating the huming weight of each number from 0~255, constructing a hash table tempHW for them
hw = [bin(x).count("1") for x in range(256)]
tempHW = [hw[s] for s in tempSbox]

# %%
#the statistic of HW value for each traces(0~8bit), like tempTracesHW[0] value means the number of the first round for how many 0 bit result. 
tempTracesHW = [[] for _ in range(9)]
for i in range(len(tempTraces)):
    HW = tempHW[i]
    tempTracesHW[HW].append(tempTraces[i])
tempTracesHW = [np.array(tempTracesHW[HW]) for HW in range(9)]

# %%
tempTraces = tempTraces[25:30]

# %%
import numpy as np


# 计算每列的均值
traces_means = np.mean(tempTraces, axis=0)
traces_var = np.var(tempTraces, axis=0)
print(traces_means)
# Out:
# [-0.4338167  -0.08484971  0.39776055 ... -0.21855273  0.42468135
#   0.04130947]

# %%
plt.plot(traces_means)

# %%
plt.plot(traces_var[0:129])

# %%
plt.plot(traces_var)

# %%
sorted_indices = np.argsort(-traces_var)

# %%
print(sorted_indices)
# Out:
# [112 111 113 110 109 114   9  10  14  13   1   2   6   5  15   8 115  11
#    7   0   3  16   4  19  18  12  20  17  21  22  23 116  25  27  55  35
#   24 107  79  30  74  33  80  59  34  28  78 117  75  31  29  87  51  47
#   26  91 105  67  57 126  46 127  32 106  58 103  56 124  71  60  44 104
#   53 122 120  85  77  84  92  66  95 123  39 119  68  70  49  65  83  69
#   52  63  99 121  41  48  37  93  89  62  42 101  36  64  73  43  88  40
#   82  76  54 102  94 125 118  38  86 108  90  81 128  50 100  97  45  98
#   96  72  61]

# %%
print(sorted_indices)
# Out:
# [112 111 113 110 114 109  25  45  37  21  33  41  29  38  30  34  22  46
#   42  26  53  49  17  50  54  18  13  14  58  57   9 115  47  35  39  27
#   31  51  43  10  23  59  55  61 117  19  65  44  48  66  56 118  40  24
#   62  52  32  28 121  36  81   1  20  69  15  77 105 106 122 101  73  82
#  125   2 126  93  94  85  74  97 102  86  70  98  89  60  78  90  16   5
#  116   6  64   8  63 119  67  71 123   7  12   3 120 127  99 128   0  95
#   75  72 108  83 107 103  91  92   4  11 124  68  79  76  88 100 104  80
#   87  84  96]

# %%
print(sorted_indices)
# Out:
# [112 111 113 110 109 114  22  33  37  45  21  25  34  26  42  38   9  41
#   10  49  30  50  53  46  29  54  14  17   2   1  18  35  51  39  58  27
#  115  13  43   5  31   8  36  23  15  40   6  55  59  48  57  47  44  16
#   28  60  32  24   3  52  56  11   0   7  20   4 116  12  63  19  71  64
#   62  67  61  66  87  88  65  95 107  89  73  74  98  83  92  97  72  96
#   75 105  81 121  82  99  70 124 102 119  69 118  80 117  77  91 103 126
#  108  76  85 106 123 125 122 127  86 128  94  84 100  68  93  79  90 120
#  104 101  78]

# %%
print(tempKey[1])
# Out:
# [ 43 126  21  22  40 174 210 166 171 247  21 136   9 207  79  60]

# %%
import matplotlib.pyplot as plt
for i in range(1000):
    plt.plot(atkTraces[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import matplotlib.pyplot as plt
#       2 for i in range(1000):
# ----> 3     plt.plot(atkTraces[i])
#
# NameError: name 'atkTraces' is not defined
